# %%
print("Olá, mundo!")
# Out:
# Olá, mundo!

# %%
nome = "Renato"
idade = 32
altura = 1.7
dev = True

# %%
type(nome)
# Out:
# str

# %%
type(idade)
# Out:
# int

# %%
type(altura)
# Out:
# float

# %%
type(dev)
# Out:
# bool

# %%
nome = 2024

# %%
nome = 2 * 2

# %%
nome
# Out:
# 4

# %%
print(nome)
# Out:
# 4
